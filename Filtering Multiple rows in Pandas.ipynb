# %%
import pandas as pd
movies= pd.read_csv('http://bit.ly/imdbratings')

# %%
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies[(movies.duration >=200 ) & (movies.genre== 'Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
#FILTERING TWO columns
movies[(movies.content_rating== 'G' ) & (movies.genre== 'Drama')]
# Out:
#      star_rating                title content_rating  genre  duration  \
# 157          8.2   Gone with the Wind              G  Drama       238
# 168          8.2  Hachi: A Dog's Tale              G  Drama        93
# 361          8.0  Fiddler on the Roof              G  Drama       181
#
#                                            actors_list
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 168  [u'Richard Gere', u'Joan Allen', u'Cary-Hiroyu...
# 361        [u'Topol', u'Norma Crane', u'Leonard Frey']

# %%
#filtering multiple rows
movies[movies.genre.isin(['Crime', 'Drame', 'Action'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 969          7.4                              Law Abiding Citizen
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...
